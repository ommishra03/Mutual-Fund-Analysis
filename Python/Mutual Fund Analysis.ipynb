# %%
pip install openpyxl
# Out:
# Collecting openpyxl
#   Downloading openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting et-xmlfile (from openpyxl)
#   Downloading et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Downloading openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Downloading et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Installing collected packages: et-xmlfile, openpyxl
#
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    ---------------------------------------- 2/2 [openpyxl]
#
# Successfully installed et-xmlfile-2.0.0 openpyxl-3.1.5
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## Data Loading

# %%
import pandas as pd
df=pd.read_excel('top_30_mutual_funds.xlsx')
df.head(30)
# Out:
#                                           scheme_name  min_sip  min_lumpsum  \
# 0                                Quant Small Cap Fund     1000         5000
# 1                           Quant Infrastructure Fund     1000         5000
# 2                       Quant Tax Plan- Direct Growth      500          500
# 3                              Quant Multi Asset Fund     1000         5000
# 4                                Quant Flexi Cap Fund     1000         5000
# 5                                 Quant Absolute Fund     1000         5000
# 6                                   Quant Active Fund     1000         5000
# 7                                  Quant Mid Cap Fund     1000         5000
# 8                PGIM India Midcap Opportunities Fund     1000         5000
# 9                                 Tata Small Cap Fund      150         5000
# 10                                    SBI Contra Fund      500         5000
# 11                       Canara Robeco Small Cap Fund     1000         5000
# 12                        Nippon India Small Cap Fund      100         5000
# 13                                AXIS Small Cap Fund      500          500
# 14                               Kotak Small Cap Fund      500          500
# 15  Kotak Multi Asset Allocator FoF – Dynamic – Di...     1000         5000
# 16                            Tata Digital India Fund      150         5000
# 17                            Kotak India Growth Fund        0         5000
# 18                  ICICI Pru Thematic Advantage Fund     1000         5000
# 19   Kotak Infrastructure & Ecoc. Reform-SP-DirGrowth     1000         5000
# 20                   AXIS FTP – Series 104 – 1112Days        0            0
# 21           ICICI Pru BHARAT 22 FOF  – Direct Growth     1000         5000
# 22                     ICICI Pru Asset Allocator Fund     1000         5000
# 23                            ICICI Pru Smallcap Fund      100         5000
# 24                                HSBC Small Cap Fund      500         5000
# 25               ICICI Pru Dividend Yield Equity Fund      100         5000
# 26                                 SBI Small Cap Fund      500         5000
# 27                       HDFC Retirement Savings Fund      100          100
# 28                                HDFC Small Cap Fund      100          100
# 29                        Parag Parikh Flexi Cap Fund     1000         1000
#
#     expense_ratio  fund_size_cr  fund_age_yr            fund_manager  sortino  \
# 0            0.64          3301           10          Sanjeev Sharma     3.71
# 1            0.64           822           10            Vasav Sahgal     3.44
# 2            0.57          2779           10            Vasav Sahgal     3.50
# 3            0.56           634           10            Vasav Sahgal     3.23
# 4            0.58          1044           10            Vasav Sahgal     3.65
# 5            0.56          1013           10          Sanjeev Sharma     3.75
# 6            0.58          3531           10          Sanjeev Sharma     3.33
# 7            0.63          1550           10          Sanjeev Sharma     3.58
# 8            0.46          7707            9          Aniruddha Naha     4.61
# 9            0.26          3300            4  Chandraprakash Padiyar     3.98
# 10           0.91          8340           10     Dinesh Balachandran     4.43
# 11           0.47          4831            4   Shridatta Bhandwaldar     4.62
# 12           0.86         23910           10             Samir Rachh     4.20
# 13           0.54         11462            9           Anupam Tiwari     3.90
# 14           0.59          8617           10         Pankaj Tibrewal     4.06
# 15           0.13           783           10        Devender Singhal     4.33
# 16           0.31          6765            7            Meeta Shetty     2.29
# 17           0.34            90            5        Devender Singhal     3.71
# 18           0.25           958           10         Dharmesh Kakkad     4.13
# 19           1.00           727           10         Harish Krishnan     4.55
# 20           0.13           110            4             Devang Shah     7.27
# 21           0.08            89            5           Kayzad Eghlim     2.76
# 22           0.18         18393           10         Dharmesh Kakkad     5.89
# 23           0.81          4618           10           Harish Bihani     4.72
# 24           0.77          8625            9       Venugopal Manghat     4.16
# 25           0.66          1258            9        Mittul Kalawadia     5.06
# 26           0.70         15395           10            R Srinivasan     4.07
# 27           0.78          2696            7   Srinivasan Ramamurthy     4.32
# 28           0.80         14648           10         Chirag Setalvad     3.75
# 29           0.75         29953           10          Rajeev Thakkar     3.06
#
#     alpha     sd  ...  risk_level                      amc_name  rating  \
# 0   19.16  24.75  ...           6             Quant Mutual Fund       5
# 1   27.24  19.24  ...           6             Quant Mutual Fund       5
# 2   17.63  19.74  ...           6             Quant Mutual Fund       5
# 3   19.52  18.63  ...           6             Quant Mutual Fund       5
# 4   15.93  19.16  ...           6             Quant Mutual Fund       5
# 5   16.98  14.41  ...           6             Quant Mutual Fund       5
# 6   13.82  19.65  ...           6             Quant Mutual Fund       0
# 7   11.21  18.73  ...           6             Quant Mutual Fund       5
# 8    6.90  18.52  ...           6        PGIM India Mutual Fund       5
# 9   11.28  17.43  ...           6              Tata Mutual Fund       4
# 10  15.26  16.56  ...           6               SBI Mutual Fund       5
# 11  12.23  17.75  ...           6     Canara Robeco Mutual Fund       5
# 12  10.01  19.31  ...           6      Nippon India Mutual Fund       4
# 13   8.34  14.71  ...           6              Axis Mutual Fund       5
# 14   8.99  18.26  ...           6    Kotak Mahindra Mutual Fund       4
# 15   8.04  10.99  ...           5    Kotak Mahindra Mutual Fund       0
# 16   6.11  22.78  ...           6              Tata Mutual Fund       0
# 17   7.67  17.23  ...           6    Kotak Mahindra Mutual Fund       0
# 18   6.63  18.22  ...           6  ICICI Prudential Mutual Fund       0
# 19  14.15  16.65  ...           6    Kotak Mahindra Mutual Fund       4
# 20   5.29      -  ...           2              Axis Mutual Fund       0
# 21   9.68   20.2  ...           6  ICICI Prudential Mutual Fund       5
# 22   7.45   8.68  ...           4  ICICI Prudential Mutual Fund       4
# 23   8.49  18.41  ...           6  ICICI Prudential Mutual Fund       3
# 24   9.87  17.95  ...           6              HSBC Mutual Fund       3
# 25  10.39  15.42  ...           6  ICICI Prudential Mutual Fund       0
# 26   6.48  16.81  ...           6               SBI Mutual Fund       4
# 27   9.26  15.16  ...           6              HDFC Mutual Fund       5
# 28   6.54  19.61  ...           6              HDFC Mutual Fund       3
# 29  10.65  14.53  ...           6             PPFAS Mutual Fund       5
#
#              category                         sub_category returns_1yr  \
# 0              Equity               Small Cap Mutual Funds         5.4
# 1              Equity     Sectoral / Thematic Mutual Funds         5.6
# 2              Equity                    ELSS Mutual Funds         0.9
# 3              Hybrid  Multi Asset Allocation Mutual Funds        10.6
# 4              Equity                      Flexi Cap Funds         6.8
# 5              Hybrid       Aggressive Hybrid Mutual Funds         7.3
# 6              Equity                      Multi Cap Funds         1.0
# 7              Equity                 Mid Cap Mutual Funds         8.8
# 8              Equity                 Mid Cap Mutual Funds         2.0
# 9              Equity               Small Cap Mutual Funds        17.1
# 10             Equity                         Contra Funds        15.0
# 11             Equity               Small Cap Mutual Funds        -0.6
# 12             Equity               Small Cap Mutual Funds         8.7
# 13             Equity               Small Cap Mutual Funds         3.4
# 14             Equity               Small Cap Mutual Funds        -0.7
# 15              Other                        FoFs Domestic        11.2
# 16             Equity     Sectoral / Thematic Mutual Funds       -16.0
# 17             Equity                      Multi Cap Funds         4.8
# 18              Other                        FoFs Domestic         5.4
# 19             Equity     Sectoral / Thematic Mutual Funds        23.2
# 20               Debt                 Fixed Maturity Plans        11.2
# 21              Other                        FoFs Domestic        22.1
# 22              Other                        FoFs Domestic         8.8
# 23             Equity               Small Cap Mutual Funds         7.7
# 24             Equity               Small Cap Mutual Funds         5.1
# 25             Equity                 Dividend Yield Funds         8.5
# 26             Equity               Small Cap Mutual Funds         8.2
# 27  Solution Oriented                     Retirement Funds        11.6
# 28             Equity               Small Cap Mutual Funds        12.5
# 29             Equity                      Flexi Cap Funds         2.3
#
#    returns_3yr  returns_5yr  composite_score  rank
# 0         71.4    23.200000         0.667338     1
# 1         61.5    21.100000         0.657207     2
# 2         54.9    22.200000         0.619385     3
# 3         42.6    20.500000         0.590916     4
# 4         47.7    18.200000         0.581508     5
# 5         38.2    19.100000         0.575243     6
# 6         45.5    19.900000         0.571100     7
# 7         45.1    19.800000         0.570889     8
# 8         42.9    19.000000         0.563725     9
# 9         44.1     9.490726         0.555885    10
# 10        43.4    15.600000         0.548635    11
# 11        51.8     9.490726         0.546916    12
# 12        47.6    16.800000         0.545914    13
# 13        34.5    19.400000         0.544876    14
# 14        43.1    17.000000         0.543357    15
# 15        25.0    15.300000         0.539607    16
# 16        39.0    22.100000         0.535081    17
# 17        35.5    15.600000         0.532532    18
# 18        35.4    14.600000         0.531927    19
# 19        39.7    13.900000         0.527864    20
# 20        14.5    14.000000         0.527290    21
# 21        35.0     9.490726         0.527151    22
# 22        21.6    12.800000         0.523626    23
# 23        41.8    14.900000         0.522774    24
# 24        44.7    12.700000         0.520291    25
# 25        37.6    12.100000         0.517556    26
# 26        38.3    15.300000         0.515483    27
# 27        34.9    14.800000         0.511836    28
# 28        43.5    13.500000         0.511312    29
# 29        33.6    17.600000         0.510861    30
#
# [30 rows x 22 columns]

# %%
print(df.describe())
# Out:
#            min_sip   min_lumpsum  expense_ratio  fund_size_cr  fund_age_yr  \
# count   814.000000    814.000000     814.000000    814.000000   814.000000
# mean    528.500000   3047.468059       0.713231   3812.854214     8.319410
# std     369.184517   2514.619513       0.482161   7181.479475     2.640622
# min       0.000000      0.000000       0.000000      2.380000     1.000000
# 25%     150.000000    500.000000       0.310000    175.250000     6.000000
# 50%     500.000000   5000.000000       0.615000    940.500000    10.000000
# 75%    1000.000000   5000.000000       1.030000   3819.000000    10.000000
# max    2000.000000  25000.000000       2.590000  57052.000000    17.000000
#
#        risk_level      rating  returns_1yr  returns_3yr  returns_5yr
# count  814.000000  814.000000   814.000000   793.000000   647.000000
# mean     4.400491    2.641278     3.921376    18.525347     9.490726
# std      1.814741    1.463476     6.675502    12.108476     3.714015
# min      1.000000    0.000000   -19.700000     3.300000    -4.100000
# 25%      3.000000    2.000000     1.500000     6.200000     6.700000
# 50%      6.000000    3.000000     4.400000    18.500000     8.900000
# 75%      6.000000    4.000000     5.600000    27.100000    12.200000
# max      6.000000    5.000000   130.800000    71.400000    23.200000

# %%
df['category'].unique()
# Out:
# array(['Other', 'Hybrid', 'Solution Oriented', 'Equity', 'Debt'],
#       dtype=object)

# %%
df.isnull().sum()
# Out:
# scheme_name        0
# min_sip            0
# min_lumpsum        0
# expense_ratio      0
# fund_size_cr       0
# fund_age_yr        0
# fund_manager       0
# sortino            0
# alpha              0
# sd                 0
# beta               0
# sharpe             0
# risk_level         0
# amc_name           0
# rating             0
# category           0
# sub_category       0
# returns_1yr        0
# returns_3yr       21
# returns_5yr      167
# dtype: int64

# %% [markdown]
# ## Data Cleaning

# %%
# Replace missing values in returns_3yr and returns_5yr
mean_returns_3yr = df['returns_3yr'].mean()
mean_returns_5yr = df['returns_5yr'].mean()
df['returns_3yr'].fillna(mean_returns_3yr, inplace=True)
df['returns_5yr'].fillna(mean_returns_5yr, inplace=True)
print(df.isnull().sum())
# Out:
# scheme_name      0
# min_sip          0
# min_lumpsum      0
# expense_ratio    0
# fund_size_cr     0
# fund_age_yr      0
# fund_manager     0
# sortino          0
# alpha            0
# sd               0
# beta             0
# sharpe           0
# risk_level       0
# amc_name         0
# rating           0
# category         0
# sub_category     0
# returns_1yr      0
# returns_3yr      0
# returns_5yr      0
# dtype: int64

# %% [markdown]
# ## Data Normalization

# %%
from sklearn.preprocessing import MinMaxScaler

columns_to_normalize = ['expense_ratio', 'returns_1yr', 'returns_3yr', 'returns_5yr', 
                        'sharpe', 'sortino', 'alpha', 'beta']
df[columns_to_normalize] = df[columns_to_normalize].replace('-', pd.NA).apply(pd.to_numeric)

scaler = MinMaxScaler()
df_normalized = pd.DataFrame(scaler.fit_transform(df[columns_to_normalize]), columns=columns_to_normalize)

# Adjust metrics where lower is better
df_normalized['expense_ratio'] = 1 - df_normalized['expense_ratio']
df_normalized['beta'] = 1 - df_normalized['beta']

# %% [markdown]
# ## Composite Scoring

# %%
weights = {
    'expense_ratio': 0.2,
    'returns_1yr': 0.15,
    'returns_3yr': 0.15,
    'returns_5yr': 0.15,
    'sharpe': 0.1,
    'sortino': 0.1,
    'alpha': 0.1,
    'beta': 0.05
}

df_normalized['composite_score'] = sum(
    df_normalized[col] * weight for col, weight in weights.items()
)
df['composite_score'] = df_normalized['composite_score']

# %% [markdown]
# ## Ranking Fund

# %%
df['rank'] = df['composite_score'].rank(ascending=False)
df_sorted = df.sort_values(by='rank')

# %% [markdown]
# ## Exporting Result

# %%
df_top_30 = df_sorted.head(30)
df_top_30.to_excel('top_30_mutual_funds.xlsx', index=False)
print("Exported top 30 mutual funds to 'top_30_mutual_funds.xlsx'.")
# Out:
# Exported top 30 mutual funds to 'top_30_mutual_funds.xlsx'.
